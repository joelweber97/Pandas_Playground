# %% [markdown]
# # Section 7: MultiIndex

# %% [markdown]
# ### Intro to the MultiIndex module

# %%
import pandas as pd

# %%
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'])
mac.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
mac.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Price in US Dollars           float64
# dtype: object

# %%
mac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# ### Create a MultiIndex on a DataFrame with the .set_index() method

# %%
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'])
mac.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
mac.set_index(keys = ['Date', 'Country'])
#can input a list into the .set_index() method to create a multiindex df
#the date is the outer level index
#the country is the internal layer index
#the order of the list input determines the order of the order of the keys in the multiindex
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Brazil                        3.35
#            Britain                       4.22
#            Canada                        4.14
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
#most outer index should be the column with the least number of unique values.
mac.nunique()
#can se that we have 12 unique dates and 58 unique countries and 330 unique prices
# Out:
# Date                    12
# Country                 58
# Price in US Dollars    330
# dtype: int64

# %%
mac.set_index(keys = ['Date', 'Country'], inplace = True)
mac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
#can also sort these index's like any normal df
mac.sort_index(inplace = True)
#this will actually sort ALL the index's. It'll start by sorting the outermost level and working inward
#the earliest date will be first and the last date will be last. Within each date the countries will be sorted alphabetically.

# %%
mac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
mac.index
#returns a multiindex object. that's really just a list of tuples consisting of the combinations of index's.
#to find a value of a cell 1 spcific index label isn't enough. We can't search for a date and get a specific cell back.
#we need to also put input the country label to find that specific cell we're looking for.
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
mac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
#another way to create a multiindex on the read
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
mac.head()

# %% [markdown]
# ### Extract Index Level Values with the .get_level_values() method

# %%
#easier way to create a multiindex df
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
mac.sort_index(inplace = True)
mac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
#invoked on the index of a multiIndex DF
#extracts all the values from a level of a multiindex
#accepts the name or the index position of the level you want to extract
mac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
#invoked on the index of a multiIndex DF
#extracts all the values from a level of a multiindex
#accepts the name or the index position of the level you want to extract
mac.index.get_level_values('Date')
mac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
mac.index.get_level_values(1)
mac.index.get_level_values('Country')
#note that the date and country are both 652 values in length.
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# ### Change the Index Level Name with the .set_names() method

# %%
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
mac.sort_index(inplace = True)
mac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
#set_names() is also called on the index of the df
mac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
mac.index.set_names(['Day', 'Location'],inplace = True)
#the first parameter is the names.
#can pass in a list of new names if you want to change all the names
mac.head()
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
#if you only want change one you can still pass in a list and keep the same name in that list.
#mac.index.set_names(['Day', 'Country'],inplace=True)
#another way of doing this is by using the level parameter
#can pass in the index position or the name of the current index name
mac.index.set_names('Date', level=0)
mac.index.set_names('Date', level='Day',inplace = True)
mac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %% [markdown]
# ### The .sort_index() method on a MultiIndex DataFrame

# %%
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
mac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
mac.sort_index()
#sorts the outermost level in ascending order (oldest to newest)
#then sorts the inner level in ascending order (alphabetically a to z)
#since the default argument for the ascending parameter is True
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
#can also pass false in the ascnding parameter
mac.sort_index(ascending = False)
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                       2.67
#            Venezuela                     0.66
#            Uruguay                       3.74
#            United States                 4.93
#            Ukraine                       1.54
# ...                                       ...
# 2010-01-01 Canada                        3.97
#            Britain                       3.67
#            Brazil                        4.76
#            Australia                     3.98
#            Argentina                     1.84
#
# [652 rows x 1 columns]

# %%
#can customize the sort order for each level
mac.sort_index(ascending = [True, False])
mac.sort_index(ascending = [False, True], inplace=True)
mac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Austria                   3.76
#            Belgium                   4.25
#            Brazil                    3.35

# %%
#can also sort a single index using the level parameter
mac.sort_index(level = 0)
mac.sort_index(level = "Date")
#both sort the date index ascending but leave the country index in the same order it was in
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
mac.sort_index(level=1)
mac.sort_index(level='Country')
#this sorts only by country.
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
# 2010-07-01 Argentina                 3.56
# 2011-07-01 Argentina                 4.84
# 2012-01-01 Argentina                 4.64
# 2012-07-01 Argentina                 4.16
# ...                                   ...
# 2014-01-01 Vietnam                   2.84
# 2014-07-01 Vietnam                   2.83
# 2015-01-01 Vietnam                   2.81
# 2015-07-01 Vietnam                   2.75
# 2016-01-01 Vietnam                   2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# ### Extract Rows from a MultiIndex DataFrame using the .loc[] and .iloc[] accessor

# %%
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
mac.sort_index(inplace = True)
mac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
#first we cover an alternate method of doing this that isn't really preferred.
mac.loc['2010-01-01','Argentina']
#usually when using .loc[] the first argument refers to the index and the second argument refers to the column
#here the first argument refers to the first index and the second argument refers to the second column.
#so this syntax doesn't reallly match up with the standard pandas way of using .loc
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
#better option
#pass a tuple in with the index labels as the first argument and the second argument is the column/s name you want to target in a list
mac.loc[('2010-01-01', 'Argentina'), 'Price in US Dollars']
# Out:
# Date        Country
# 2010-01-01  Argentina    1.84
# Name: Price in US Dollars, dtype: float64

# %%
#multiIndex's don't affect iloc at all
#each row is still given an index position in line
#row 1 will be the first row in line.
#doesn't start counting within each level, starts counting from the top.
mac.iloc[0]
mac.iloc[500]
# Out:
# Price in US Dollars    4.75
# Name: (2015-01-01 00:00:00, Finland), dtype: float64

# %%
mac.iloc[200:500:50]
# Out:
#                         Price in US Dollars
# Date       Country
# 2012-07-01 Argentina                   4.16
#            Turkey                      4.52
# 2013-01-01 South Korea                 3.41
# 2013-07-01 Philippines                 2.65
# 2014-01-01 Mexico                      2.78
# 2014-07-01 Indonesia                   2.43

# %%
mac.iloc[[10,30,40,300,301,500]]
# Out:
#                         Price in US Dollars
# Date       Country
# 2010-01-01 Denmark                     5.99
#            Singapore                   3.19
#            Ukraine                     1.83
# 2013-01-01 South Korea                 3.41
#            Spain                       4.75
# 2015-01-01 Finland                     4.75

# %% [markdown]
# ### The .transpose() method on a MultiIndex DataFrame

# %%
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
mac.sort_index(inplace = True)
mac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
#swaps the index's of the df.
#row labels are now the column headers
#takes the column headers and move them to the row labels.
mac.transpose()
#actually creates multiindex columns
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
#tranpose doesn't mutate a df nor does it have an inplace parameter so we have to assign it back to a varaible
mac = mac.transpose()
mac.head()
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
#slicing using the .loc[] accessor after transpose
mac.loc[("Price in US Dollars",),('2010-01-01',)]
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...                   \
# Country             Colombia Costa Rica Czech Republic  ... Sri Lanka Sweden
# Price in US Dollars     3.91       3.52           3.71  ...      1.83   5.51
#
# Date                                                                  \
# Country             Switzerland Taiwan Thailand Turkey   UAE Ukraine
# Price in US Dollars         6.3   2.36     2.11   3.83  2.99    1.83
#
# Date
# Country             United States Uruguay
# Price in US Dollars          3.58    3.32
#
# [1 rows x 43 columns]

# %%
mac.loc[('Price in US Dollars',), ('2010-01-01','Sri Lanka')]
# Out:
# Date                2010-01-01
# Country              Sri Lanka
# Price in US Dollars       1.83

# %%
mac.loc[('Price in US Dollars',),('2010-01-01',)].values
# Out:
# array([[1.84, 3.98, 4.76, 3.67, 3.97, 3.18, 1.83, 3.91, 3.52, 3.71, 5.99,
#         2.38, 4.84, 1.91, 3.86, 2.24, 3.99, 3.5 , 3.09, 2.87, 2.08, 2.5 ,
#         3.61, 7.02, 2.42, 2.81, 2.21, 2.86, 2.34, 2.67, 3.19, 2.46, 2.98,
#         1.83, 5.51, 6.3 , 2.36, 2.11, 3.83, 2.99, 1.83, 3.58, 3.32]])

# %%
#.loc[] slicing also works on multiIndex df
#pull out values of sri lanka through ukraine for jan 1 2010
mac.loc[('Price in US Dollars',),('2010-01-01','Sri Lanka'):('2010-01-01','Ukraine')]
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83

# %% [markdown]
# ### The .swaplevel() method

# %%
mac = pd.read_csv('./data/bigmac.csv', parse_dates = ['Date'], index_col = ['Date','Country'])
mac.sort_index(inplace = True)
mac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
#use the index name for the two index's you want to swap
mac.swaplevel('Date','Country')
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
#can also use index positions to swap
mac.swaplevel(0,1)
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
#non mutable and doesn't include inplace parameter so we'll have to overwrite the variable manually
mac = mac.swaplevel(0,1)

# %% [markdown]
# ### The .stack() method

# %%
world = pd.read_csv('./data/worldstats.csv', index_col = ['country','year'])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
#.stack() takes the column axis and moves it to the main index
world.stack()
#there are now twice as many rows and only 1 column
#this really creates a single row series with 3 levels in index
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
type(world.stack())
# Out:
# pandas.core.series.Series

# %%
#can also keep it as a df, rather than the series it created.
world.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %% [markdown]
# ### The .unstack() method, Part 1

# %%
world = pd.read_csv('./data/worldstats.csv', index_col = ['country','year'])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
#gonna call the stack method first to create the 3 level index we saw in the lesson above
s = world.stack()

# %%
s.head()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
# dtype: float64

# %%
s.unstack()
#innermost layer (population and gdp) is moved back into the column names
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
s.unstack().unstack() 
#innermost 2 layers (population/gdp and year) are moved to the columns
# Out:
#                       Population                                            \
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %%
s.unstack().unstack().unstack()
#all 3 index levels have been moved into the columns.
# Out:
#             year  country
# Population  1960  Afghanistan           8.994793e+06
#                   Albania                        NaN
#                   Algeria               1.112489e+07
#                   Andorra                        NaN
#                   Angola                         NaN
#                                             ...
# GDP         2015  West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Yemen, Rep.                    NaN
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 28224, dtype: float64

# %% [markdown]
# ### The .unstack() method, Part 2

# %%
world = pd.read_csv('./data/worldstats.csv', index_col = ['country','year'])
world.head(3)
s =world.stack()
s.head()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
# dtype: float64

# %%
#various parameters that can be added to the method to specify which index level will be added to the columns
#s.unstack(level = -1, fill_value = None)
#the level is index location of the index level
#outer most index (Country) has a index location of 0
#next level (year) has an index location of 1.
#level = -1 is the inner most index. Similar to the -1 index of a list being the last value.

# %%
#want to move year into the columns
s.unstack(level = 1)
#moves year across the top and country and pop/gdp down the side
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %%
#this sets the countries across the top and has a multiIndex of the year and pop/gdp
s.unstack(level = 0)
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %%
# can also use -n for the level
s.unstack(level = -1) #which is the same as s.unstack(2)
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
s.unstack(level = -2)
#this is the same as level = 1
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %%
#can also write the string name for the index
s.unstack('country')
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %%
s.unstack('year')
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %% [markdown]
# ### The .unstack() method, Part 3

# %%
world = pd.read_csv('./data/worldstats.csv', index_col = ['country','year'])
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
#can unstack by multiple levels to columns axis in 1 move.
#can pass in a list with the index positions or the index name to unstack those levels
s.unstack(level = [0,1])
s.unstack(level = ['country','year'])
#order matters. First number in list will be outer most column header
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s.unstack(level = [1,0])
s.unstack(level = ['year','country'])
# Out:
# year                2015          2014          2013          2012  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# year                2011          2010          2009          2008  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# year                2007          2006  ...          1969          1968  \
# country       Arab World    Arab World  ...      Zimbabwe      Zimbabwe
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# year                1967          1966          1965          1964  \
# ...

# %%
s.unstack([2,0])
# Out:
#           Population           GDP             Population  \
# country   Arab World    Arab World Caribbean small states
# year
# 1960             NaN           NaN              4190810.0
# 1961             NaN           NaN              4270928.0
# 1962             NaN           NaN              4353408.0
# 1963             NaN           NaN              4435830.0
# 1964             NaN           NaN              4514432.0
# 1965             NaN           NaN              4586896.0
# 1966             NaN           NaN              4653340.0
# 1967             NaN           NaN              4713767.0
# 1968     115557094.0  2.552596e+10              4770152.0
# 1969     118823872.0  2.817577e+10              4825706.0
# 1970     122128175.0  3.109149e+10              4882583.0
# 1971     125439089.0  3.610721e+10              4940523.0
# 1972     128801209.0  4.296931e+10              4999973.0
# 1973     132298955.0  5.459015e+10              5060335.0
# ...

# %%
s = s.unstack('year', fill_value = 0)
s
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %% [markdown]
# ### The .pivot() method

# %%
#.pivot() is used to re-orient a dataset
#it takes values in a column and converts them to column headers

# %%
sales = pd.read_csv('./data/salesmen.csv',parse_dates= ['Date'])
#of the 1830 rows there are only 5 salesman so we'll convert that to category
sales['Salesman'] = sales['Salesman'].astype('category')
sales.head()
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982
# 3 2016-01-04      Bob     7917
# 4 2016-01-05      Bob     7837

# %%
#we want to take the 5 different salesman that occur i nthe salesman column and move that to column headers.
sales = sales.pivot(index = 'Date', columns = 'Salesman', values = 'Revenue')
sales.head(3)
#index is the column we want to be the index after the pivot
#columns is the column values we want to take and spread across the top
#values are what we want to input into the cells under each saleman column.
#not usefull if the columns parameter has a lot of different values in that original column.
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703

# %%
#makes it easier to do math on a specific salesman or across dates. We can see which date had the most sale
sales.sum(axis = 1).max(axis = 0)
# Out:
# 43087

# %% [markdown]
# ### Use the .pivot_table() method to create an aggregate summary of a DataFrame

# %%
#works exactly the same as it does in xcel

# %%
foods = pd.read_csv('./data/foods.csv')
foods[['Gender','City','Frequency','Item']] = foods[['Gender','City','Frequency','Item']].astype('category')
foods.head(3)
# Out:
#   First Name  Gender      City Frequency     Item  Spend
# 0      Wanda  Female  Stamford    Weekly   Burger  15.66
# 1       Eric    Male  Stamford     Daily  Chalupa  10.56
# 2    Charles    Male  New York     Never    Sushi  42.14

# %%
#average spent per gender
foods.pivot_table(values = 'Spend', index = 'Gender', aggfunc = 'mean')
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
#total sales per city
foods.pivot_table(values = 'Spend', index='City', aggfunc = 'sum')
# Out:
#                  Spend
# City
# New York      15809.57
# Philadelphia  17834.54
# Stamford      16425.26

# %%
#total sales by item
foods.pivot_table(values = 'Spend',index='Item',aggfunc = 'sum').sort_values('Spend')
# Out:
#              Spend
# Item
# Chalupa    7644.52
# Burger     7765.73
# Burrito    8270.44
# Sushi      8742.93
# Donut      8758.76
# Ice Cream  8886.99

# %%
#how much each gender bought of each item.
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], aggfunc = 'sum')
#as you can see, passing in a list as the index parameter returns a multiIndex series
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
#we can also add more columns to make it into a df
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = 'City', aggfunc = 'mean')
# Out:
# City               New York  Philadelphia   Stamford
# Gender Item
# Female Burger     51.626667     52.878710  45.037778
#        Burrito    42.563043     52.098571  53.532647
#        Chalupa    46.135789     52.291563  64.094000
#        Donut      46.670323     54.642000  48.734118
#        Ice Cream  56.356296     46.225625  46.910455
#        Sushi      47.751290     58.096000  45.622187
# Male   Burger     58.822273     44.675238  46.424516
#        Burrito    55.976000     43.764333  46.438929
#        Chalupa    49.110800     48.444783  50.011304
#        Donut      44.842333     37.859394  49.004483
#        Ice Cream  55.297586     53.445610  42.368800
#        Sushi      51.709259     49.852857  70.434444

# %%
#can also have a multiindex columns
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = ['Frequency','City'],aggfunc = 'mean')
# Out:
# Frequency             Daily                            Monthly               \
# City               New York Philadelphia   Stamford   New York Philadelphia
# Gender Item
# Female Burger     43.778333    77.226667  48.220000  57.286667    53.762500
#        Burrito    44.890000    53.595000  39.126000  40.913333    17.140000
#        Chalupa    43.190000    23.490000  95.700000  79.185000    72.490000
#        Donut      39.841667    61.850000  41.450000  71.132500    50.250000
#        Ice Cream  65.547500    59.230000  46.440000  46.265000    37.255000
#        Sushi      40.535000    58.088333  56.181429  46.580000    78.710000
# Male   Burger     63.892000    37.566667  49.430000  62.430000    71.046667
#        Burrito    78.736667    41.440000  69.057500  49.180000    29.860000
#        Chalupa    27.045000    68.702500  48.160000  66.752000    45.350000
#        Donut      46.000000    47.677500  64.710000  45.932500    51.858000
# ...

# %%
#total spend on each item in each city for each gender
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = ['City'],aggfunc = 'sum')
#average spent on each item in each city for each gender
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = ['City'],aggfunc = 'mean')
#number of that item in each city by gender
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = ['City'],aggfunc = 'count')
#the max in the spend column for each item in each city for each gender
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = ['City'],aggfunc = 'max')
#the min in the spend column for each item in each city for each gender
foods.pivot_table(values = 'Spend', index = ['Gender','Item'], columns = ['City'],aggfunc = 'min')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger         2.25          1.97      6.24
#        Burrito        1.02          1.04      1.18
#        Chalupa        1.96          9.35      9.09
#        Donut          3.15          2.13      1.68
#        Ice Cream     13.39          7.61      8.80
#        Sushi          2.52         11.68      8.20
# Male   Burger         5.43          1.71      2.83
#        Burrito       15.90          8.58      3.64
#        Chalupa       11.61          1.94     10.56
#        Donut          1.49          1.26      6.63
#        Ice Cream     14.06          4.89      3.43
#        Sushi          3.28          2.01     32.15

# %% [markdown]
# ### Use the pd.melt() method to create a narrow dataset from a wide one

# %%
#works as the reverse operation of a pivot() method
#takes an aggregated dataset and turns it into tabular format.
sales = pd.read_csv('./data/quarters.csv')
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(sales, id_vars = 'Salesman')
#new 3 column dataset that keeps the salesman and adds a variable column (value that was initially stored as column header)
#and the value associated with that salesman/quarter combination.
#condensed the column headers into a single row and added necessary salesman to match
# Out:
#    Salesman variable   value
# 0     Boris       Q1  602908
# 1       Bob       Q1   43790
# 2     Tommy       Q1  392668
# 3    Travis       Q1  834663
# 4    Donald       Q1  580935
# 5       Ted       Q1  656644
# 6       Jeb       Q1  486141
# 7     Stacy       Q1  479662
# 8    Morgan       Q1  992673
# 9     Boris       Q2  233879
# 10      Bob       Q2  514863
# 11    Tommy       Q2  113579
# 12   Travis       Q2  266785
# 13   Donald       Q2  411379
# 14      Ted       Q2   70803
# 15      Jeb       Q2  600753
# 16    Stacy       Q2  742806
# 17   Morgan       Q2  879183
# 18    Boris       Q3  354479
# 19      Bob       Q3  297151
# 20    Tommy       Q3  430882
# 21   Travis       Q3  749238
# 22   Donald       Q3  110390
# 23      Ted       Q3  375948
# 24      Jeb       Q3  742716
# 25    Stacy       Q3  770712
# 26   Morgan       Q3   37945
# 27    Boris       Q4   32704
# 28      Bob       Q4  544493
# 29    Tommy       Q4  247231
# 30   Travis       Q4  570524
# ...

# %%
#we can change the column names so they're not variable and value in the melted dataset
test = pd.melt(sales, id_vars = 'Salesman', var_name = 'Quarter', value_name = 'Revenue')

# %%
test
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...

# %%
#reverse of the pd.melt method is the .pivot() method
test.pivot(index = 'Salesman', columns = 'Quarter',values = 'Revenue')
# Out:
# Quarter       Q1      Q2      Q3      Q4
# Salesman
# Bob        43790  514863  297151  544493
# Boris     602908  233879  354479   32704
# Donald    580935  411379  110390  651572
# Jeb       486141  600753  742716  404995
# Morgan    992673  879183   37945  293710
# Stacy     479662  742806  770712    2501
# Ted       656644   70803  375948  321388
# Tommy     392668  113579  430882  247231
# Travis    834663  266785  749238  570524
